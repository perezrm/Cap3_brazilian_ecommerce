# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import numpy as np # linear algebra
import statsmodels.api as sm
import statsmodels.formula.api as smf
import matplotlib.ticker as mtick # For specifying the axes tick format
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns # For creating plots
from datetime import date

# %% [markdown]
# ### customers | olist_customers_dataset CSV

# %%
customers = pd.read_csv('olist_customers_dataset.csv', sep=',')
customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
# customer_id                 99441 non-null object
# customer_unique_id          99441 non-null object
# customer_zip_code_prefix    99441 non-null int64
# customer_city               99441 non-null object
# customer_state              99441 non-null object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %% [markdown]
# ### orders | olist_orders_dataset CSV

# %%
orders = pd.read_csv('olist_orders_dataset.csv', sep=',')
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
# order_id                         99441 non-null object
# customer_id                      99441 non-null object
# order_status                     99441 non-null object
# order_purchase_timestamp         99441 non-null object
# order_approved_at                99281 non-null object
# order_delivered_carrier_date     97658 non-null object
# order_delivered_customer_date    96476 non-null object
# order_estimated_delivery_date    99441 non-null object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %% [markdown]
# ### new_test MERGE customers, orders

# %%
new_test = pd.merge(customers,orders)
new_test.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %%
# MERDEd customers,orders
new_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99441 entries, 0 to 99440
# Data columns (total 12 columns):
# customer_id                      99441 non-null object
# customer_unique_id               99441 non-null object
# customer_zip_code_prefix         99441 non-null int64
# customer_city                    99441 non-null object
# customer_state                   99441 non-null object
# order_id                         99441 non-null object
# order_status                     99441 non-null object
# order_purchase_timestamp         99441 non-null object
# order_approved_at                99281 non-null object
# order_delivered_carrier_date     97658 non-null object
# order_delivered_customer_date    96476 non-null object
# order_estimated_delivery_date    99441 non-null object
# dtypes: int64(1), object(11)
# memory usage: 9.9+ MB

# %% [markdown]
# ### order_payments | olist_order_payments_dataset CSV

# %%
order_payments = pd.read_csv('olist_order_payments_dataset.csv', sep=',')
order_payments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
order_payments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
# order_id                103886 non-null object
# payment_sequential      103886 non-null int64
# payment_type            103886 non-null object
# payment_installments    103886 non-null int64
# payment_value           103886 non-null float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %% [markdown]
# ### new_table MERGE new_test/ customers, orders | order_payments

# %%
new_table = pd.merge(new_test,order_payments)
new_table.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %%
# new_table MERGEd new_test/ customers, orders | order_payments

new_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103886 entries, 0 to 103885
# Data columns (total 16 columns):
# customer_id                      103886 non-null object
# customer_unique_id               103886 non-null object
# customer_zip_code_prefix         103886 non-null int64
# customer_city                    103886 non-null object
# customer_state                   103886 non-null object
# order_id                         103886 non-null object
# order_status                     103886 non-null object
# order_purchase_timestamp         103886 non-null object
# order_approved_at                103711 non-null object
# order_delivered_carrier_date     101998 non-null object
# order_delivered_customer_date    100754 non-null object
# order_estimated_delivery_date    103886 non-null object
# payment_sequential               103886 non-null int64
# payment_type                     103886 non-null object
# payment_installments             103886 non-null int64
# ...

# %% [markdown]
# ## order_items | olist_order_items_dataset CSV

# %%
order_items = pd.read_csv('olist_order_items_dataset.csv', sep=',')
order_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %% [markdown]
# ### freight_value is the shipping cost

# %%
order_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
# order_id               112650 non-null object
# order_item_id          112650 non-null int64
# product_id             112650 non-null object
# seller_id              112650 non-null object
# shipping_limit_date    112650 non-null object
# price                  112650 non-null float64
# freight_value          112650 non-null float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %% [markdown]
# ## products | olist_products_dataset CSV

# %%
products = pd.read_csv('olist_products_dataset.csv', sep=',')
products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
# product_id                    32951 non-null object
# product_category_name         32341 non-null object
# product_name_lenght           32341 non-null float64
# product_description_lenght    32341 non-null float64
# product_photos_qty            32341 non-null float64
# product_weight_g              32949 non-null float64
# product_length_cm             32949 non-null float64
# product_height_cm             32949 non-null float64
# product_width_cm              32949 non-null float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %% [markdown]
# #### order_reviews | olist_order_reviews_dataset CSV

# %%
order_reviews = pd.read_csv('olist_order_reviews_dataset.csv', sep=',')
order_reviews.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
order_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 7 columns):
# review_id                  100000 non-null object
# order_id                   100000 non-null object
# review_score               100000 non-null int64
# review_comment_title       11715 non-null object
# review_comment_message     41753 non-null object
# review_creation_date       100000 non-null object
# review_answer_timestamp    100000 non-null object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %% [markdown]
# ### new_table2 MERGE new_table MERGEd new_test/ customers, orders, order_payments | order_reviews

# %%
new_table2 = pd.merge(new_table,order_reviews)
new_table2.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %%
# customers, orders, order_payments | order_reviews
new_table2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 104485 entries, 0 to 104484
# Data columns (total 22 columns):
# customer_id                      104485 non-null object
# customer_unique_id               104485 non-null object
# customer_zip_code_prefix         104485 non-null int64
# customer_city                    104485 non-null object
# customer_state                   104485 non-null object
# order_id                         104485 non-null object
# order_status                     104485 non-null object
# order_purchase_timestamp         104485 non-null object
# order_approved_at                104309 non-null object
# order_delivered_carrier_date     102587 non-null object
# order_delivered_customer_date    101331 non-null object
# order_estimated_delivery_date    104485 non-null object
# payment_sequential               104485 non-null int64
# payment_type                     104485 non-null object
# payment_installments             104485 non-null int64
# ...

# %% [markdown]
# ### new_table3 MERGE new_table2/customers, orders, order_payments | order_items

# %%
new_table3 = pd.merge(new_table2,order_items)
new_table3.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %%
new_table3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 118315 entries, 0 to 118314
# Data columns (total 28 columns):
# customer_id                      118315 non-null object
# customer_unique_id               118315 non-null object
# customer_zip_code_prefix         118315 non-null int64
# customer_city                    118315 non-null object
# customer_state                   118315 non-null object
# order_id                         118315 non-null object
# order_status                     118315 non-null object
# order_purchase_timestamp         118315 non-null object
# order_approved_at                118300 non-null object
# order_delivered_carrier_date     117061 non-null object
# order_delivered_customer_date    115727 non-null object
# order_estimated_delivery_date    118315 non-null object
# payment_sequential               118315 non-null int64
# payment_type                     118315 non-null object
# payment_installments             118315 non-null int64
# ...

# %% [markdown]
# ### MERGE

# %%
new_table4 = pd.merge(new_table3, products)
new_table4
# Out:
#                              customer_id                customer_unique_id  \
# 0       06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1       8912fc0c3bbf1e2fbf35819e21706718  9eae34bbd3a474ec5d07949ca7de67c0
# 2       8912fc0c3bbf1e2fbf35819e21706718  9eae34bbd3a474ec5d07949ca7de67c0
# 3       f0ac8e5a239118859b1734e1087cbb1f  3c799d181c34d51f6d44bbbc563024db
# 4       6bc8d08963a135220ed6c6d098831f84  23397e992b09769faf5e66f9e171a241
# ...                                  ...                               ...
# 118310  da37711b17efd5f2539e8196ab215f04  5f2971f9805e3ccb030226e30c8e8390
# 118311  184e0c2cfc746789643521df0e9ff904  c64ede6d0ae8901b1b6fb03528c1b7e6
# 118312  821a7275a08f32975caceff2e08ea262  046470763123d3d6364f89095b4e47ab
# 118313  1ed0c832c2dd99570a59260e71768bdf  82d46759af0369aad49084bacf85a6c3
# 118314  1ed0c832c2dd99570a59260e71768bdf  82d46759af0369aad49084bacf85a6c3
#
# ...

# %%
new_table4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 118315 entries, 0 to 118314
# Data columns (total 36 columns):
# customer_id                      118315 non-null object
# customer_unique_id               118315 non-null object
# customer_zip_code_prefix         118315 non-null int64
# customer_city                    118315 non-null object
# customer_state                   118315 non-null object
# order_id                         118315 non-null object
# order_status                     118315 non-null object
# order_purchase_timestamp         118315 non-null object
# order_approved_at                118300 non-null object
# order_delivered_carrier_date     117061 non-null object
# order_delivered_customer_date    115727 non-null object
# order_estimated_delivery_date    118315 non-null object
# payment_sequential               118315 non-null int64
# payment_type                     118315 non-null object
# payment_installments             118315 non-null int64
# ...

# %% [markdown]
# # below

# %%
# test_join = pd.concat([customers, orders], axis=0, join='inner',keys=['customer_id'])
# test_join.head()

# %%
order_items = pd.read_csv('olist_order_items_dataset.csv', sep=',')

# %%
order_reviews = pd.read_csv('olist_order_reviews_dataset.csv', sep=',')

# %%
products = pd.read_csv('olist_products_dataset.csv', sep=',')

# %%
product_category = pd.read_csv('product_category_name_translation.csv', sep=',')

# %%
combined_table = pd.merge(new_table4, product_category)
combined_table.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  8912fc0c3bbf1e2fbf35819e21706718  9eae34bbd3a474ec5d07949ca7de67c0
# 2  8912fc0c3bbf1e2fbf35819e21706718  9eae34bbd3a474ec5d07949ca7de67c0
# 3  f0ac8e5a239118859b1734e1087cbb1f  3c799d181c34d51f6d44bbbc563024db
# 4  6bc8d08963a135220ed6c6d098831f84  23397e992b09769faf5e66f9e171a241
#
#    customer_zip_code_prefix    customer_city customer_state  \
# 0                     14409           franca             SP
# 1                     68030         santarem             PA
# 2                     68030         santarem             PA
# 3                     92480  nova santa rita             RS
# 4                     25931             mage             RJ
#
#                            order_id order_status order_purchase_timestamp  \
# 0  00e7ee1b050b8499577073aeb2a297a1    delivered      2017-05-16 15:05:35
# ...

# %%
combined_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 116581 entries, 0 to 116580
# Data columns (total 37 columns):
# customer_id                      116581 non-null object
# customer_unique_id               116581 non-null object
# customer_zip_code_prefix         116581 non-null int64
# customer_city                    116581 non-null object
# customer_state                   116581 non-null object
# order_id                         116581 non-null object
# order_status                     116581 non-null object
# order_purchase_timestamp         116581 non-null object
# order_approved_at                116567 non-null object
# order_delivered_carrier_date     115368 non-null object
# order_delivered_customer_date    114066 non-null object
# order_estimated_delivery_date    116581 non-null object
# payment_sequential               116581 non-null int64
# payment_type                     116581 non-null object
# payment_installments             116581 non-null int64
# ...

# %%
joined_table = combined_table.drop(columns=['review_comment_title', 'review_comment_message'])
joined_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 116581 entries, 0 to 116580
# Data columns (total 35 columns):
# customer_id                      116581 non-null object
# customer_unique_id               116581 non-null object
# customer_zip_code_prefix         116581 non-null int64
# customer_city                    116581 non-null object
# customer_state                   116581 non-null object
# order_id                         116581 non-null object
# order_status                     116581 non-null object
# order_purchase_timestamp         116581 non-null object
# order_approved_at                116567 non-null object
# order_delivered_carrier_date     115368 non-null object
# order_delivered_customer_date    114066 non-null object
# order_estimated_delivery_date    116581 non-null object
# payment_sequential               116581 non-null int64
# payment_type                     116581 non-null object
# payment_installments             116581 non-null int64
# ...

# %%
# Pandas dropna() method allows the user to analyze and drop Rows/Columns with Null values in different ways
joined_table.dropna(inplace = True)
joined_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 114050 entries, 0 to 116580
# Data columns (total 35 columns):
# customer_id                      114050 non-null object
# customer_unique_id               114050 non-null object
# customer_zip_code_prefix         114050 non-null int64
# customer_city                    114050 non-null object
# customer_state                   114050 non-null object
# order_id                         114050 non-null object
# order_status                     114050 non-null object
# order_purchase_timestamp         114050 non-null object
# order_approved_at                114050 non-null object
# order_delivered_carrier_date     114050 non-null object
# order_delivered_customer_date    114050 non-null object
# order_estimated_delivery_date    114050 non-null object
# payment_sequential               114050 non-null int64
# payment_type                     114050 non-null object
# payment_installments             114050 non-null int64
# ...

# %%
joined_table.head(20)
# Out:
#                          customer_id                customer_unique_id  \
# 0   06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1   8912fc0c3bbf1e2fbf35819e21706718  9eae34bbd3a474ec5d07949ca7de67c0
# 2   8912fc0c3bbf1e2fbf35819e21706718  9eae34bbd3a474ec5d07949ca7de67c0
# 3   f0ac8e5a239118859b1734e1087cbb1f  3c799d181c34d51f6d44bbbc563024db
# 4   6bc8d08963a135220ed6c6d098831f84  23397e992b09769faf5e66f9e171a241
# 5   fd3a0b1bd209f0e7d420c9c3d1127613  567ab47ca4deb92d46dbf54dce07d0a7
# 6   fbd40c083aa8cddebb5265b2ba6aaf2e  f40ab89b622248b7ca125af4b486b887
# 7   10558ef4afea173bfb5e2cbe3d5b0bb5  749943913a9851a39c9baf51877fbab6
# 8   1c37c0f0cd1d88d46d9fc9494762abbd  432ecfa8b7b7ad2663c7abed0dc83c51
# 9   20a452f528d487411fd7d3ebda1d0f20  31318a0597cd9d50ce4cfd03c80fe780
# 10  20a452f528d487411fd7d3ebda1d0f20  31318a0597cd9d50ce4cfd03c80fe780
# 11  62f766c82849282806bf2f62ca86432e  83aca63b2193ea126b287f3ae61528d9
# ...

# %%
# joined_table.drop_duplicates(inplace=True)

joined_table.drop_duplicates(subset ="order_id", 
                     keep = 'first', inplace = True) 
joined_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 95109 entries, 0 to 116580
# Data columns (total 35 columns):
# customer_id                      95109 non-null object
# customer_unique_id               95109 non-null object
# customer_zip_code_prefix         95109 non-null int64
# customer_city                    95109 non-null object
# customer_state                   95109 non-null object
# order_id                         95109 non-null object
# order_status                     95109 non-null object
# order_purchase_timestamp         95109 non-null object
# order_approved_at                95109 non-null object
# order_delivered_carrier_date     95109 non-null object
# order_delivered_customer_date    95109 non-null object
# order_estimated_delivery_date    95109 non-null object
# payment_sequential               95109 non-null int64
# payment_type                     95109 non-null object
# payment_installments             95109 non-null int64
# ...

# %%
payorder_cust = pd.merge(orders, order_payments)
payorder_cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103886 entries, 0 to 103885
# Data columns (total 12 columns):
# order_id                         103886 non-null object
# customer_id                      103886 non-null object
# order_status                     103886 non-null object
# order_purchase_timestamp         103886 non-null object
# order_approved_at                103711 non-null object
# order_delivered_carrier_date     101998 non-null object
# order_delivered_customer_date    100754 non-null object
# order_estimated_delivery_date    103886 non-null object
# payment_sequential               103886 non-null int64
# payment_type                     103886 non-null object
# payment_installments             103886 non-null int64
# payment_value                    103886 non-null float64
# dtypes: float64(1), int64(2), object(9)
# memory usage: 10.3+ MB

# %%
payorder_customer = payorder_cust.drop(columns=['order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date', 'order_estimated_delivery_date'])
payorder_customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103886 entries, 0 to 103885
# Data columns (total 8 columns):
# order_id                    103886 non-null object
# customer_id                 103886 non-null object
# order_status                103886 non-null object
# order_purchase_timestamp    103886 non-null object
# payment_sequential          103886 non-null int64
# payment_type                103886 non-null object
# payment_installments        103886 non-null int64
# payment_value               103886 non-null float64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 7.1+ MB

# %%
# formula = 'order_purchase_timestamp ~ payment_value'

# fitted_model = smf.ols(formula=formula, data=payorder_customer).fit()
# fitted_model.summary()

# %% [markdown]
# # Charts and Graph

# %%
joined_table2 = joined_table.drop(columns=['customer_unique_id', 'order_approved_at', 'order_status'])
joined_table2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 95109 entries, 0 to 116580
# Data columns (total 32 columns):
# customer_id                      95109 non-null object
# customer_zip_code_prefix         95109 non-null int64
# customer_city                    95109 non-null object
# customer_state                   95109 non-null object
# order_id                         95109 non-null object
# order_purchase_timestamp         95109 non-null object
# order_delivered_carrier_date     95109 non-null object
# order_delivered_customer_date    95109 non-null object
# order_estimated_delivery_date    95109 non-null object
# payment_sequential               95109 non-null int64
# payment_type                     95109 non-null object
# payment_installments             95109 non-null int64
# payment_value                    95109 non-null float64
# review_id                        95109 non-null object
# review_score                     95109 non-null int64
# ...

# %%
# Histograms below
numeric_vars = ['payment_value', 'price', 'freight_value', 'product_weight_g']
categorical_vars = ['product_category_name ']

# %%
# Histograms
ax = joined_table2[numeric_vars].hist(bins=5)
plt.tight_layout()

# %%
# Single variable regression
joined_table2.plot('price', 'freight_value', kind='scatter');

# %% [markdown]
# # Price

# %%
formula = 'price ~ payment_value + product_weight_g + freight_value + C(payment_type)'

fitted_model = smf.ols(formula=formula, data=joined_table2).fit()
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.823
# Model:                            OLS   Adj. R-squared:                  0.823
# Method:                 Least Squares   F-statistic:                 7.393e+04
# Date:                Wed, 04 Dec 2019   Prob (F-statistic):               0.00
# Time:                        23:47:36   Log-Likelihood:            -5.5133e+05
# No. Observations:               95109   AIC:                         1.103e+06
# Df Residuals:                   95102   BIC:                         1.103e+06
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# # Freight_value

# %%
formula = 'freight_value ~ payment_value + product_weight_g + C(payment_type)'

fitted_model = smf.ols(formula=formula, data=joined_table2).fit()
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          freight_value   R-squared:                       0.440
# Model:                            OLS   Adj. R-squared:                  0.440
# Method:                 Least Squares   F-statistic:                 1.494e+04
# Date:                Wed, 04 Dec 2019   Prob (F-statistic):               0.00
# Time:                        23:33:24   Log-Likelihood:            -3.7015e+05
# No. Observations:               95109   AIC:                         7.403e+05
# Df Residuals:                   95103   BIC:                         7.404e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# ...

# %%
olist_data = joined_table2.drop(columns=['order_delivered_carrier_date', 'order_delivered_customer_date', 'order_estimated_delivery_date', 'payment_sequential', 'payment_installments', 'review_creation_date', 'review_answer_timestamp', 'seller_id', 'shipping_limit_date', 'freight_value', 'product_name_lenght', 'product_description_lenght', 'product_weight_g', 'product_length_cm', 'product_height_cm', 'product_width_cm', 'product_category_name'])
olist_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 95109 entries, 0 to 116580
# Data columns (total 15 columns):
# customer_id                      95109 non-null object
# customer_zip_code_prefix         95109 non-null int64
# customer_city                    95109 non-null object
# customer_state                   95109 non-null object
# order_id                         95109 non-null object
# order_purchase_timestamp         95109 non-null object
# payment_type                     95109 non-null object
# payment_value                    95109 non-null float64
# review_id                        95109 non-null object
# review_score                     95109 non-null int64
# order_item_id                    95109 non-null int64
# product_id                       95109 non-null object
# price                            95109 non-null float64
# product_photos_qty               95109 non-null float64
# product_category_name_english    95109 non-null object
# ...

# %% [markdown]
# ### olist_data joined table

# %%
olist_data.head()
# Out:
#                         customer_id  customer_zip_code_prefix  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7                     14409
# 1  8912fc0c3bbf1e2fbf35819e21706718                     68030
# 3  f0ac8e5a239118859b1734e1087cbb1f                     92480
# 4  6bc8d08963a135220ed6c6d098831f84                     25931
# 5  fd3a0b1bd209f0e7d420c9c3d1127613                     88460
#
#      customer_city customer_state                          order_id  \
# 0           franca             SP  00e7ee1b050b8499577073aeb2a297a1
# 1         santarem             PA  c1d2b34febe9cd269e378117d6681172
# 3  nova santa rita             RS  b1a5d5365d330d10485e0203d54ab9e8
# 4             mage             RJ  2e604b3614664aa66867856dba7e61b7
# 5         angelina             SC  574fe1739f65af76badd0999db300b4f
#
#   order_purchase_timestamp payment_type  payment_value  \
# 0      2017-05-16 15:05:35  credit_card         146.87
# 1      2017-11-09 00:50:13  credit_card         275.79
# ...

# %%
olist_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 95109 entries, 0 to 116580
# Data columns (total 15 columns):
# customer_id                      95109 non-null object
# customer_zip_code_prefix         95109 non-null int64
# customer_city                    95109 non-null object
# customer_state                   95109 non-null object
# order_id                         95109 non-null object
# order_purchase_timestamp         95109 non-null object
# payment_type                     95109 non-null object
# payment_value                    95109 non-null float64
# review_id                        95109 non-null object
# review_score                     95109 non-null int64
# order_item_id                    95109 non-null int64
# product_id                       95109 non-null object
# price                            95109 non-null float64
# product_photos_qty               95109 non-null float64
# product_category_name_english    95109 non-null object
# ...

# %% [markdown]
# # Regression models

# %%
formula = 'payment_value ~ C(customer_state)'

fitted_model = smf.ols(formula=formula, data=olist_data).fit()
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          payment_value   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     33.21
# Date:                Wed, 04 Dec 2019   Prob (F-statistic):          1.90e-164
# Time:                        21:52:31   Log-Likelihood:            -6.4592e+05
# No. Observations:               95109   AIC:                         1.292e+06
# Df Residuals:                   95082   BIC:                         1.292e+06
# Df Model:                          26
# Covariance Type:            nonrobust
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# ...

# %%
sns.scatterplot(x = 'customer_state' , y = 'payment_value', data = joined_table2,)

plt.title('Customer by State Vs Payment Value');

# %%
formula = 'payment_value ~ C(payment_type)'

fitted_model = smf.ols(formula=formula, data=olist_data).fit()
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          payment_value   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     156.5
# Date:                Wed, 04 Dec 2019   Prob (F-statistic):          3.45e-101
# Time:                        21:52:32   Log-Likelihood:            -6.4611e+05
# No. Observations:               95109   AIC:                         1.292e+06
# Df Residuals:                   95105   BIC:                         1.292e+06
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# ...

# %%
formula = 'price ~ C(payment_type)'

fitted_model = smf.ols(formula=formula, data=olist_data).fit()
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     101.8
# Date:                Wed, 04 Dec 2019   Prob (F-statistic):           9.16e-66
# Time:                        23:07:36   Log-Likelihood:            -6.3364e+05
# No. Observations:               95109   AIC:                         1.267e+06
# Df Residuals:                   95105   BIC:                         1.267e+06
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# ...

# %%
country_amount = pd.value_counts(olist_data.customer_state).to_frame()
country_amount
# Out:
#     customer_state
# SP           39942
# RJ           12167
# MG           11185
# RS            5264
# PR            4855
# SC            3492
# BA            3214
# DF            2050
# ES            1978
# GO            1911
# PE            1575
# CE            1265
# PA             928
# MT             874
# MA             708
# MS             692
# PB             509
# PI             469
# RN             468
# AL             393
# SE             333
# TO             271
# RO             238
# AM             144
# AC              78
# AP              67
# RR              39

# %%
ax = sns.barplot(x="customer_zip_code_prefix", y="payment_value", data=olist_data)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-117-cfa55513b2d7> in <module>
# ----> 1 ax = sns.barplot(x="customer_zip_code_prefix", y="payment_value", data=olist_data)
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3147                           estimator, ci, n_boot, units,
#    3148                           orient, color, palette, saturation,
# -> 3149                           errcolor, errwidth, capsize, dodge)
#    3150
#    3151     if ax is None:
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
# ...

# %%
fig, ax = plt.subplots()
olist_data.plot(kind='scatter', x='order_purchase_timestamp', y='payment_value', ax=ax)

# Turn on the grid
ax.grid()

# %%
ax = sns.scatterplot(x = 'order_purchase_timestamp', y = 'payment_value', data = olist_data)
# ax.set_xlim(2016,2018)

# %%
# fig = plt.figure(figsize=(20,12))
# ax = fig.gca()
# ax = sns.scatterplot(x="customer_state", y="payment_value", style="payment_type", hue="customer_state", data=olist_data)

# %%
# formula = 'order_purchase_timestamp ~ payment_value'

# fitted_model = smf.ols(formula=formula, data=olist_data).fit()
# fitted_model.summary()

# %%
# olist_data.groupby(['order_purchase_timestamp']).groups.keys()

# %%
# olist_data['order_purchase_timestamp'].max()

# %%
# olist_data['order_purchase_timestamp'].min()

# %%
# olist_data.groupby(
#     ['customer_id']
# ).agg(
#     {'order_purchase_timestamp': [max]})

# %%
# olist_data['order_purchase_timestamp'] = pd.to_datetime(olist_data['order_purchase_timestamp'])
# olist_data.info()

# %%
# inactive_date = date(2018, 1, 1)
# print(inactive_date)

# %%
ax = sns.scatterplot(x = 'order_purchase_timestamp', y = 'payment_value', data = olist_data)
# ax.set_xlim(2016,2018)

# %%
ax = sns.barplot(x="customer_zip_code_prefix", y="payment_value", data=olist_data)
